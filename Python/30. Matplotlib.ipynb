# %% [markdown]
# ## 18.1.1 Matplotlib
#
# * Its a python library used for plotting graphs.
# * It uses general puprose GUI toolkits to plot graphs
# * It contains pyplot module which provides an interface very similar to MATLAB. it can be used as an open-source free alternative of MATLAB.
# * [Click here](https://matplotlib.org/index.html) for official documentation website of MATPLOTLIB.

# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.pyplot import pie, axis, show

# %matplotlib inline                                                              

import warnings                                                                 # Ignore warning related to pandas_profiling
warnings.filterwarnings('ignore') 

from numpy.random import randn, randint, uniform, sample

# %%
# create a pandas dataframe
# with a dummy data = random 1000 nos generated by numpy.
# with index = data range from date 
df = pd.DataFrame(np.random.randn(1000), 
                  index = pd.date_range('2020-08-08', periods = 1000), 
                  columns=['value'])

# create a series dataframe for time series
# with a dummy data = random 1000 nos generated by numpy.
# with index = data range from date 
ts = pd.Series(np.random.randn(1000), 
               index = pd.date_range('2020-08-08', periods = 1000))

# %%
df
# Out:
#                value
# 2020-08-08  1.843814
# 2020-08-09 -1.529238
# 2020-08-10  0.555443
# 2020-08-11  2.038462
# 2020-08-12  0.338257
# ...              ...
# 2023-04-30  0.269700
# 2023-05-01 -0.121668
# 2023-05-02  1.557425
# 2023-05-03 -0.047810
# 2023-05-04  0.178110
#
# [1000 rows x 1 columns]

# %%
ts
# Out:
# 2020-08-08    0.155898
# 2020-08-09   -0.306132
# 2020-08-10   -1.427284
# 2020-08-11   -0.222889
# 2020-08-12   -1.407945
#                 ...
# 2023-04-30   -1.585067
# 2023-05-01    0.066003
# 2023-05-02    0.281666
# 2023-05-03   -0.701837
# 2023-05-04    0.351548
# Freq: D, Length: 1000, dtype: float64

# %%
df.sample(5)
# Out:
#                value
# 2022-10-09  2.187703
# 2023-04-29  0.267344
# 2022-01-01 -0.335004
# 2021-07-30 -1.034057
# 2021-09-13 -0.203742

# %%
#### Pandas dataframe and series have inbuilt plot method which can be used as shown below -

# %%
df.plot()
# Out:
# <Axes: >

# %%
#### > **NOTE**: Since the plot looks cluttered so you can specify figure size as figure size = (width, height) for creating desired size plot

# %%
df.plot(figsize=(10,5))
# Out:
# <Axes: >

# %%
ts.plot(figsize=(20,5))
# Out:
# <Axes: >

# %%
df['value'] = df['value'].cumsum()
df
# Out:
#                value
# 2020-08-08  1.843814
# 2020-08-09  0.314576
# 2020-08-10  0.870019
# 2020-08-11  2.908481
# 2020-08-12  3.246739
# ...              ...
# 2023-04-30  1.416041
# 2023-05-01  1.294373
# 2023-05-02  2.851798
# 2023-05-03  2.803988
# 2023-05-04  2.982097
#
# [1000 rows x 1 columns]

# %%
# plotting commulative sum -
df.plot(figsize=(20,5))
# Out:
# <Axes: >

# %%
ts = ts.cumsum()
ts
# Out:
# 2020-08-08     0.155898
# 2020-08-09    -0.150234
# 2020-08-10    -1.577518
# 2020-08-11    -1.800407
# 2020-08-12    -3.208352
#                 ...
# 2023-04-30   -33.149960
# 2023-05-01   -33.083957
# 2023-05-02   -32.802291
# 2023-05-03   -33.504128
# 2023-05-04   -33.152580
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
# Out:
# <Axes: >

# %%
# import seaborn library
import seaborn as sns

# load iris dataset
iris = sns.load_dataset('iris')
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.species
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
iris["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# Lets create normal line plot using plot method on pandas dataframe.
# here we have specified title of the graph.

iris.plot(figsize=(20,5), title = "IRIS Dataset");

# %%
iris.plot(figsize=(20,5), title = "IRIS Dataset")
# Out:
# <Axes: title={'center': 'IRIS Dataset'}>

# %%
# plotting bar plot for first 10 entry of the iris datset.
# Here we have specified kind = bar to plot the bar graphs.
# Plus we are using iloc method on pandas datframe to get first 10 data points
iris.iloc[:10].plot(figsize=(20,5), title = "IRIS Dataset",  kind="bar")
# Out:
# <Axes: title={'center': 'IRIS Dataset'}>

# %%
# lets try to keep the numerical values only
# use drop method to drop "sepcies" column
iris_num = iris.drop(["species"], axis=1)

# %%
iris_num
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
# plotting 0th datapoint as a bar
iris_num.iloc[2].plot(kind="bar")
# Out:
# <Axes: >

# %%
# and alternative of above method is you can use bar method 
# instead of using kind parameter
iris_num.iloc[0].plot.bar()
# Out:
# <Axes: >

# %%
# load titanic dataset from seaborn
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# plot histogram of pclass column to see how the data is distributed
titanic['pclass'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
# lets generate a random normal values of shape 10 rows and 4 columns
random_no_in_shape_10by4 = np.random.randn(10, 4)


# create a df by using above data and lets also assign
# names of the 4 columns
random_df = pd.DataFrame(random_no_in_shape_10by4, 
                         columns=['a', 'b', 'c', 'd']) 

# lets see the first 10 datapoints
random_df.head(10)
# Out:
#           a         b         c         d
# 0 -0.238332 -0.785434 -2.193560  0.886330
# 1 -0.595713 -2.355482 -0.286478 -1.485252
# 2 -1.871765  0.928729 -1.816561  0.724552
# 3  0.157736 -1.341516 -1.649535 -1.808415
# 4  1.614170 -0.584194  0.987265  0.826988
# 5 -0.306155  1.332722  0.503406 -1.400337
# 6 -0.084503 -0.349986 -0.077357  0.077239
# 7  1.626662  0.830213 -1.401200 -0.430789
# 8  0.582181 -0.834066 -0.143441 -2.982412
# 9 -0.255758  0.926474  0.782078  0.742635

# %%
# plot bar graph
random_df.plot.bar()
# Out:
# <Axes: >

# %%
# alternative way to plot the graph
random_df.plot(kind = "bar")
# Out:
# <Axes: >

# %%
# plot graph horontally
random_df.plot(kind = "barh")
# Out:
# <Axes: >

# %%
# plot graph horontally
random_df.plot.barh()
# Out:
# <Axes: >

# %% [markdown]
# #### 18.1.1.3 Histograms
#
# it was introduced by *Karl Pearson*. It is a representation of numerical data in a form of bar graphs. Following is a bried explaination: -
#
# * BINS: these are nothing division of entire range of values into some specific series of intervals. These intervals are non overlapping.
# * Then we plot the count of values or frequency of values which fall in these bins or buckets in form of a bar
#
# For more information you can refer - [Histogram (WIKIPEDIA)](https://en.wikipedia.org/wiki/Histogram)

# %%
# plot historgram for iris dataset
# this plots the distribution of all the columns in one graph
iris.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# you can plot historgam of one column as shown below
iris['sepal_length'].hist()
# Out:
# <Axes: >

# %%
iris['sepal_width'].hist(bins =[2,4,8])
# Out:
# <Axes: >

# %%
# alternative way to plot histogram
iris.plot(kind ="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
# here we have plotted stacked bar graph with bins = 50
# to observe difference between stacked and unstacked lets plot 
# both the cases
# case 1: stacked = True {default case}
iris.plot(kind = 'hist', stacked = True, bins = 50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 iris.diff().hist(color = 'r', alpha = 0.5, figsize=(10,10))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9738, in DataFrame.diff(self, periods, axis)
#    9735     # With periods=0 this is equivalent to a diff with axis=0
#    9736     axis = 0
# -> 9738 new_data = self._mgr.diff(n=periods)
#    9739 res_df = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    9740 return res_df.__finalize__(self, "diff")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:403, in BaseBlockManager.diff(self, n)
#     401 def diff(self, n: int) -> Self:
#     402     # only reached with self.ndim == 2
# --> 403     return self.apply("diff", n=n)
#
# ...

# %%
# drop the species column
iris_df1 = iris.drop(['species'], axis = 1)

# %%
iris_df1.diff().hist(color = 'r', alpha = 0.5, figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets

# Load the iris dataset
iris = datasets.load_iris()
iris_data = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Create a distribution plot with a curve using seaborn
sns.set(style="whitegrid")
for column in iris_data.columns:
    sns.kdeplot(iris_data[column], shade=True)

plt.title("Distribution Plot with Curve for Iris Dataset")
plt.xlabel("Data Value")
plt.ylabel("Density")
plt.show()

# %%
iris_data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
# Create a distribution plot with a curve using seaborn
sns.set(style="whitegrid")
sns.kdeplot(iris_data["sepal length (cm)"], shade = True)
sns.kdeplot(iris_data["sepal width (cm)"], shade = True)
sns.kdeplot(iris_data["petal length (cm)"], shade = True)
sns.kdeplot(iris_data["petal width (cm)"], shade = True)

plt.title("Distribution Plot with Curve for Iris Dataset")
plt.xlabel("Data Value")
plt.ylabel("Density")
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for the pie chart
sizes = [25, 20, 15, 40]  # Example data percentages for pink, brown, yellow, red
colors = ['pink', 'brown', 'yellow', 'red']
labels = ['Pink', 'Brown', 'Yellow', 'Red']

# Create a pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title("Pie Chart with Custom Colors")
plt.show()

# %%
plt.pie(iris1["species"],  colors=colors, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title("Pie Chart with Custom Colors")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 plt.pie(iris1["species"],  colors=colors, autopct='%1.1f%%', startangle=140)
#       2 plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#       4 plt.title("Pie Chart with Custom Colors")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3546, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3523 @_copy_docstring_and_deprecators(Axes.pie)
#    3524 def pie(
#    3525     x: ArrayLike,
#    (...)
#    3544     data=None,
#    3545 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3546     return gca().pie(
#    3547         x,
#    3548         explode=explode,
# ...

# %%
# load iris dataset
iris1 = sns.load_dataset('iris')

# %%
iris1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

# Load the Iris dataset
iris = datasets.load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target

# Map numerical species to actual species names
iris_df['species'] = iris_df['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

# Count the number of occurrences of each species
species_count = iris_df['species'].value_counts()

# Create a pie chart for species distribution
plt.figure(figsize=(8, 6))
plt.pie(species_count, labels=species_count.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightgreen', 'lightcoral'])
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

plt.title("Species Distribution in Iris Dataset")
plt.show()

# %% [markdown]
# #### 18.2 BOXPLOT
# Its a kind of graph which helps to show how numerical data is spread in quartiles.
#
# We'll study more about it in Statistics lecture

# %%
import numpy as np
import pandas as pd

# import pyplot module for plotting
import matplotlib.pyplot as plt

# import warnings to ignore warning messages for now -
import warnings
warnings.filterwarnings("ignore")

# %%
# import seaborn library
import seaborn as sns

# load iris dataset to practice
iris = sns.load_dataset('iris')
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot(kind = 'box', figsize=(10, 5))
# Out:
# <Axes: >

# %%
# define custom color of boxes and whiskers
color = {'boxes': 'DarkGreen', 'whiskers': 'r'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'r'}

# %%
iris.plot(kind = 'box', figsize=(10, 5), color=color)
# Out:
# <Axes: >

# %%
# plot horizontal box plot
iris.plot(kind = 'box', figsize=(10,5), color = color, vert = False)
# Out:
# <Axes: >

# %% [markdown]
# # All The Basic Chart Of Matplotlib

# %% [markdown]
# ## line chart

# %%
import matplotlib.pyplot as plt

# Demo data
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
sales = [100, 120, 90, 110, 130]

# Plotting
plt.plot(months, sales, marker='o', linestyle='-')

# Adding labels and title
plt.xlabel('Months')
plt.ylabel('Sales')
plt.title('Sales Trend Over Time')

# Displaying the plot
plt.show()

# %% [markdown]
# ## bar chart

# %%
# Demo data
products = ['Product A', 'Product B', 'Product C']
sales = [200, 300, 250]

# Plotting
plt.bar(products, sales, color='skyblue')

# Adding labels and title
plt.xlabel('Products')
plt.ylabel('Sales')
plt.title('Sales Comparison Across Products')

# Displaying the plot
plt.show()

# %% [markdown]
# ## Histogram

# %%
# Demo data
exam_scores = [85, 90, 70, 95, 80, 75, 88, 92, 78, 85, 90, 82, 87, 89, 93]

# Plotting
plt.hist(exam_scores, bins=5, color='lightgreen', edgecolor='black')

# Adding labels and title
plt.xlabel('Exam Scores')
plt.ylabel('Frequency')
plt.title('Distribution of Exam Scores')

# Displaying the plot
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
# Demo data
study_hours = [3, 4, 5, 6, 7, 8, 9, 10]
exam_scores = [70, 75, 80, 85, 88, 90, 92, 95]

# Plotting
plt.scatter(study_hours, exam_scores, color='orange')

# Adding labels and title
plt.xlabel('Study Hours')
plt.ylabel('Exam Scores')
plt.title('Study Hours vs. Exam Scores')

# Displaying the plot
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
# Demo data
regions = ['North', 'South', 'East', 'West']
sales = [30, 20, 25, 35]

# Plotting
plt.pie(sales, labels=regions, autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'lightcoral', 'lightsalmon'])

# Adding title
plt.title('Sales Distribution Across Regions')

# Displaying the plot
plt.show()
